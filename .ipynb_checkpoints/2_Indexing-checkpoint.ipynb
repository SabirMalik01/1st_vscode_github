# %% [markdown]
#  #### Functions on string

# %%
goals = "To give my family a wonderful life with luxuries"
goals
# Out:
# 'To give my family a wonderful life with luxuries'

# %%
goals.capitalize()
# Out:
# 'To give my family a wonderful life with luxuries'

# %%
goals.upper()
# Out:
# 'TO GIVE MY FAMILY A WONDERFUL LIFE WITH LUXURIES'

# %%
goals.count

# %%
len(goals)
# Out:
# 48

# %%
goals.count("a")
# Out:
# 2

# %%
goals.count("t")
# Out:
# 1

# %%
goals.count("S")
# Out:
# 0

# %% [markdown]
# ### String indexing

# %%
help = "Allah"
help
# Out:
# 'Allah'

# %%
help[4]
# Out:
# 'h'

# %%
help[3]
# Out:
# 'a'

# %%
help.upper()
# Out:
# 'ALLAH'

# %%
help[0:5]
# Out:
# 'Allah'

# %%
help[-1]
# Out:
# 'h'

# %%
help.replace("llah","LLAH")
# Out:
# 'ALLAH'

# %%
name = "Sabir Malik"
name
# Out:
# 'Sabir Malik'

# %%
name.find("M")
# Out:
# 6

# %%
name.find("Ma")
# Out:
# 6

# %%
name.find("l")
# Out:
# 8

# %%
name.find("li")
# Out:
# 8

# %%
name.find("ik")
# Out:
# 9
